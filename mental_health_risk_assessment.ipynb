# %% [markdown]
# <a href="https://colab.research.google.com/github/nathnaeltk/ml-tech-usage-mental-health-risk-assessment/blob/main/mental_health_risk_assessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load Data

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/nathnaeltk/ml-tech-usage-mental-health-risk-assessment/refs/heads/main/mental_health_and_technology_usage_2024.csv')
df

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Convert Categorical Variables to **Numeric**

# %%
x_encoded = pd.get_dummies(x, columns=['Gender', 'Stress_Level', 'Support_Systems_Access', 'Work_Environment_Impact', 'Online_Support_Usage'], drop_first=True)

x_encoded.head()

# %% [markdown]
# ## Data Separation as x and y

# %%
y = df['Mental_Health_Status']
y
# Out:
# 0            Good
# 1            Poor
# 2            Fair
# 3       Excellent
# 4            Good
#           ...
# 9995         Good
# 9996         Fair
# 9997         Poor
# 9998         Poor
# 9999         Fair
# Name: Mental_Health_Status, Length: 10000, dtype: object

# %%
x = df.drop('Mental_Health_Status', axis = 1)
x = x.drop('User_ID', axis=1)
x
# Out:
#          User_ID  Age  Gender  Technology_Usage_Hours  \
# 0     USER-00001   23  Female                    6.57
# 1     USER-00002   21    Male                    3.01
# 2     USER-00003   51    Male                    3.04
# 3     USER-00004   25  Female                    3.84
# 4     USER-00005   53    Male                    1.20
# ...          ...  ...     ...                     ...
# 9995  USER-09996   42    Male                    7.05
# 9996  USER-09997   31   Other                    3.12
# 9997  USER-09998   23    Male                    4.38
# 9998  USER-09999   38    Male                    4.44
# 9999  USER-10000   41    Male                    2.50
#
#       Social_Media_Usage_Hours  Gaming_Hours  Screen_Time_Hours Stress_Level  \
# 0                         6.00          0.68              12.36          Low
# 1                         2.57          3.74               7.61         High
# 2                         6.14          1.26               3.16         High
# ...

# %% [markdown]
# ## **Data Splitting**

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 100)

x_train
# Out:
#          User_ID  Age  Gender  Technology_Usage_Hours  \
# 8369  USER-08370   26    Male                    8.84
# 9722  USER-09723   42   Other                    4.46
# 6950  USER-06951   56   Other                    3.03
# 1919  USER-01920   33  Female                    8.75
# 5713  USER-05714   30    Male                    6.03
# ...          ...  ...     ...                     ...
# 350   USER-00351   60  Female                    4.74
# 79    USER-00080   21    Male                    6.24
# 8039  USER-08040   52   Other                    5.41
# 6936  USER-06937   38    Male                    5.75
# 5640  USER-05641   37    Male                    1.37
#
#       Social_Media_Usage_Hours  Gaming_Hours  Screen_Time_Hours Stress_Level  \
# 8369                      2.96          0.04               3.07       Medium
# 9722                      6.14          2.21               6.71       Medium
# 6950                      4.87          0.03               4.62          Low
# ...

# %% [markdown]
# # **Building the Model**

# %% [markdown]
# ## **Linear Regression**

# %% [markdown]
# ## Training the model

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(x_train, y_train)

LinearRegression()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-d376453251e9> in <cell line: 5>()
#       3 lr = LinearRegression()
#       4
# ----> 5 lr.fit(x_train, y_train)
#       6
#       7 LinearRegression()
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     607         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     608
# --> 609         X, y = self._validate_data(
#     610             X,
#     611             y,
#
# ...

# %% [markdown]
# ### Applying Mdoel to make a Prediction

# %%
y_lr_train_prod =
